# %%
import numpy as np

# %% [markdown]
# Creating an numpy array

# %%
fruits = np.array(['banana', 'cherry', 'strawberry'])

print(fruits)
# Out:
# ['banana' 'cherry' 'strawberry']

# %%
print(type(fruits))
# Out:
# <class 'numpy.ndarray'>
